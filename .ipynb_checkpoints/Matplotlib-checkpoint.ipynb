# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3],[2,5,7])
plt.show()

# %%
plt.plot([1,2,3],[2,5,7])
plt.title("Gaurav Rawat Data")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
x1=[1,2,3]
y1=[2,5,7]
plt.plot(x1,y1, xlabel="X-axis")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_25004/3588840911.py in <module>
#       1 x1=[1,2,3]
#       2 y1=[2,5,7]
# ----> 3 plt.plot(x1,y1,xlabel="X-axis")
#       4 plt.show()
#
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
# ...
